# %% [markdown]
# # Assignment-1

# %%
import json

# Task 1: Create a JSON file with employee information

employee_data = [
    {
        "Name": "John",
        "DOB": "15/02/1998",
        "Height":5.5,
        "City": "vizag",
        "State": "Andhra Pradesh"
    },
    {
        "Name": "Mahesh",
        "DOB": "20/06/1997",
        "Height": 5.8,
        "City": "Warangal",
        "State": "Telangana"
    },
    {
        "Name": "Johnson",
        "DOB": "15/05/1999",
        "Height": 5.9,
        "City": "Hanamkonda",
        "State": "Telangana"
    },
    {
        "Name": "Raj kumar",
        "DOB": "20/09/1996",
        "Height": 5.8,
        "City": "Hanamkonda",
        "State": "Orissa"
    },
    {
        "Name": "David",
        "DOB": "02/08/2000",
        "Height": 5.5,
        "City": "Warangal",
        "State": "Telangana"
    }
]


with open("employee.json", "w") as json_file:
    json.dump(employee_data, json_file, indent=4)

# Task 2: Create a dictionary of Indian states and capitals and write it to a JSON file

indian_states_and_capitals = {
    "Andhra Pradesh": "Amaravati",
    "Telangana": "Hyderabad",
    "Tamil Nadu": "Chennai",
    "Karnataka": "Bengaluru",
    "Maharashtra": "Mumbai",
    "Kerala": "Thiruvananthapuram",
    "Gujarat": "Gandhinagar"
}


with open("indian_states.json", "w") as json_file:
    json.dump(indian_states_and_capitals, json_file, indent=4)



class Employee:
    def __init__(self, name, dob, height, city, state):
        self.name = name
        self.dob = dob
        self.height = height
        self.city = city
        self.state = state


with open("employee.json", "r") as json_file:
    employee_data = json.load(json_file)


employee_list = []
for emp_info in employee_data:
    employee = Employee(emp_info["Name"], emp_info["DOB"], emp_info["Height"], emp_info["City"], emp_info["State"])
    employee_list.append(employee)


for employee in employee_list:
    print(f"Name: {employee.name}, DOB: {employee.dob}, Height: {employee.height}, City: {employee.city}, State: {employee.state}")
# Out:
# Name: John, DOB: 15/02/1998, Height: 5.5, City: vizag, State: Andhra Pradesh
# Name: Mahesh, DOB: 20/06/1997, Height: 5.8, City: Warangal, State: Telangana
# Name: Johnson, DOB: 15/05/1999, Height: 5.9, City: Hanamkonda, State: Telangana
# Name: Raj kumar, DOB: 20/09/1996, Height: 5.8, City: Hanamkonda, State: Orissa
# Name: David, DOB: 02/08/2000, Height: 5.5, City: Warangal, State: Telangana

# %% [markdown]
# # Assignment-2

# %%
# Parent class 'Dog'
class Dog:
    def __init__(self, name, age, coat_color):
        self.name = name
        self.age = age
        self.coat_color = coat_color

    def description(self):
        print(f"{self.name} is {self.age} years old.")

    def get_info(self):
        print(f"{self.name}'s coat color is {self.coat_color}.")

# Child class 'JackRussellTerrier'
class JackRussellTerrier(Dog):
    def __init__(self, name, age, coat_color, hunting_skill):
        super().__init__(name, age, coat_color)
        self.hunting_skill = hunting_skill

    def bark(self):
        print(f"{self.name} the Jack Russell Terrier is barking!")

    def show_hunting_skill(self):
        print(f"{self.name} has a hunting skill level of {self.hunting_skill}.")

# Child class 'Bulldog'
class Bulldog(Dog):
    def __init__(self, name, age, coat_color, strength):
        super().__init__(name, age, coat_color)
        self.strength = strength

    def snore(self):
        print(f"{self.name} the Bulldog is snoring loudly!")

    def show_strength(self):
        print(f"{self.name} has a strength rating of {self.strength}.")

# Create objects and implement the functionalities
dog1 = JackRussellTerrier("Rusty", 3, "White and Brown", 8)
dog2 = Bulldog("Spike", 5, "Fawn", 9)

dog1.description()
dog1.get_info()
dog1.bark()
dog1.show_hunting_skill()

dog2.description()
dog2.get_info()
dog2.snore()
dog2.show_strength()
# Out:
# Rusty is 3 years old.
# Rusty's coat color is White and Brown.
# Rusty the Jack Russell Terrier is barking!
# Rusty has a hunting skill level of 8.
# Spike is 5 years old.
# Spike's coat color is Fawn.
# Spike the Bulldog is snoring loudly!
# Spike has a strength rating of 9.
